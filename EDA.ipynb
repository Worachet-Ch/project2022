# %% [markdown]
# <a href="https://colab.research.google.com/github/Worachet-Ch/project2022/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from google.colab import drive #เชื่อม Google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project' #เข้า drive
data_file_path = os.path.join(path,'dataset.csv') #ไปที่ไฟล์ confirmed-cases-since-280265.csv
dataset = pd.read_csv(data_file_path) #อ่านไฟล์ csv
# Out:
# Mounted at /content/drive

# %%
dataset
# Out:
#        No.        LabNo  Sex  AgeSYear  Enose  Overall  Body shape age  \
# 0     50.0  2.01809E+11    2        58    NaN      NaN             NaN
# 1     57.0  2.01809E+11    2        57    NaN      NaN             NaN
# 2     86.0   2.0181E+11    2        24    NaN      NaN             NaN
# 3    104.0   2.0181E+11    2        62    NaN      NaN             NaN
# 4    109.0  2.01811E+11    2        86    NaN      NaN             NaN
# ..     ...          ...  ...       ...    ...      ...             ...
# 418    NaN          V14    2        25    NaN      NaN             NaN
# 419    NaN          V17    2        31    NaN      NaN             NaN
# 420    NaN          V19    2        32    NaN      NaN             NaN
# 421    NaN          V21    1        29    NaN      NaN             NaN
# 422    NaN          V22    2        31    NaN      NaN             NaN
#
#      Kidney  Heart  Liver  ...  071_HbA1c     CK   LD-P   AMY7   TP1  DBIL  \
# ...

# %% [markdown]
# # Expolatory

# %%
dataset.shape
# Out:
# (423, 47)

# %%
dataset.describe()
# Out:
#                 No.        Sex    AgeSYear  Enose  Overall  Body shape age  \
# count    408.000000  423.00000  423.000000  102.0     12.0             0.0
# mean   10708.784314    1.70922   41.437352    1.0      1.0             NaN
# std    10003.883670    0.45466   13.056393    0.0      0.0             NaN
# min       50.000000    1.00000   19.000000    1.0      1.0             NaN
# 25%      663.750000    1.00000   31.000000    1.0      1.0             NaN
# 50%    20015.500000    2.00000   41.000000    1.0      1.0             NaN
# 75%    20677.000000    2.00000   51.000000    1.0      1.0             NaN
# max    21214.000000    2.00000   86.000000    1.0      1.0             NaN
#
#        Kidney  Heart  Liver  Pancreas  ...   071_HbA1c          CK  \
# count     4.0    0.0    0.0       8.0  ...  256.000000  174.000000
# mean      1.0    NaN    NaN       1.0  ...    5.600391   98.494253
# std       0.0    NaN    NaN       0.0  ...    1.138885   50.783315
# ...

# %%
dataset.isnull().sum()
# Out:
# No.                                      15
# LabNo                                     0
# Sex                                       0
# AgeSYear                                  0
# Enose                                   321
# Overall                                 411
# Body shape age                          423
# Kidney                                  419
# Heart                                   423
# Liver                                   423
# Pancreas                                415
# biological age from telomere length       0
# telomere length (kb)                      0
# DHEAs (BRIA)                            218
# Weight                                    8
# Height                                    8
# BMI                                       8
# Systolic                                  8
# Diastolic                                 9
# HeartRate                                51
# SMM                                     225
# ...

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure(figsize=(16,10))
sns.displot(dataset['004_Uric Acid'], bins = 30)

# %%
#fix, axes = plt.subplots(ncols=7, nrows=2, figsize=(10,5))
#i = 0
#axes = axes.flatten()
#for c,d in dataset.items():
 # sns.displot(d, ax=axes[i])
  #i = i+1
#plt.tight_layout(pad=0.5, w_pad =0.5, h_pad=3)

# %%
plt.figure(figsize=(30,20))
correlation_matrix = dataset.corr().abs().round(2)
sns.heatmap(data = correlation_matrix, annot =True)
