# %% [markdown]
# <a href="https://colab.research.google.com/github/Worachet-Ch/project2022/blob/main/fill_any_variable_by_1600_NaN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #นำเข้า pandas แทนที่ด้วย pd
import os# os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as mno
import missingno as msno
from sklearn import linear_model
# %matplotlib inline
import matplotlib
import sklearn 
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
import time

# %%
from google.colab import drive #เชื่อม Google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project' #เข้า drive
data_file_path = os.path.join(path,'data_notmissing.csv') #ไปที่ไฟล์ confirmed-cases-since-280265.csv
data = pd.read_csv(data_file_path) #อ่านไฟล์ csv
# Out:
# Mounted at /content/drive

# %%
data.drop({'Unnamed: 0','telomere length (kb) '},1,inplace = True)
# Out:
# <ipython-input-3-4cc622f169ae>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data.drop({'Unnamed: 0','telomere length (kb) '},1,inplace = True)

# %%
data
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0      107.0
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0       69.0
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# ...

# %% [markdown]
# # random NaN

# %%
X = data.drop(['Sex', 'AgeSYear', '002_BUN', '003_Creatinine', '005_Cholesterol', '006_Triglyceride', '008_HDL-C', '009_LDL', '010_AST'], axis=1)

# %%
y= data.loc[:,['Sex', 'AgeSYear', '002_BUN', '003_Creatinine', '005_Cholesterol', '006_Triglyceride', '008_HDL-C', '009_LDL', '010_AST']]

# %%
t_start = time.time()
for i in range(1,1601):
  globals()[f'X{i}'] = X.copy()
  np.random.seed(i)
  mask = np.zeros(153*17, dtype=bool)
  mask[:1600] = True
  np.random.shuffle(mask)
  mask = mask.reshape(153, 17)
  globals()[f'X{i}'][mask] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 1.6689772605895996 วินาที
# เวลาที่ใช้ในการประมวลผล 0.027816287676493325 นาที

# %%
X101
# Out:
#      Weight  Height   BMI  Systolic  Diastolic  HeartRate   SMM  Fat Mass  \
# 0      47.4   153.0  20.2       NaN        NaN        NaN   NaN       NaN
# 1       NaN     NaN   NaN       NaN       69.0        NaN  21.3       NaN
# 2      54.4   165.0  20.0       NaN       75.0        NaN  21.6       NaN
# 3       NaN     NaN  21.7      95.0        NaN        NaN   NaN       NaN
# 4       NaN     NaN   NaN       NaN        NaN      107.0   NaN      19.0
# ..      ...     ...   ...       ...        ...        ...   ...       ...
# 148     NaN     NaN  24.9       NaN        NaN       69.0   NaN       NaN
# 149    62.0     NaN   NaN     103.0        NaN        NaN  27.8      11.9
# 150     NaN     NaN  20.4       NaN       52.0        NaN   NaN       NaN
# 151     NaN   159.0   NaN     117.0       60.0       72.0   NaN       NaN
# 152    58.2     NaN   NaN     108.0        NaN       73.0   NaN      13.0
#
#      % Body fat  waist to hip radio  abdominal circumference  \
# ...

# %%
for i in range(1,1601):
  globals()[f'data_random{i}'] = y.join(globals()[f'X{i}'])

# %%
data_random10
# Out:
#      Sex  AgeSYear  002_BUN  003_Creatinine  005_Cholesterol  \
# 0      2      57.0     15.0             1.0            176.0
# 1      2      24.0     12.0             0.8            159.0
# 2      2      62.0     17.0             0.7            230.0
# 3      2      35.0     10.0             0.6            198.0
# 4      1      46.0     14.0             0.9            194.0
# ..   ...       ...      ...             ...              ...
# 148    1      60.0     14.0             0.9            182.0
# 149    1      58.0     18.0             1.0            191.0
# 150    2      42.0      9.0             0.8            212.0
# 151    2      61.0     12.0             0.8            235.0
# 152    2      31.0     12.0             0.7            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  Weight  ...  Fat Mass  \
# 0                51.0       72.0     94.0     16.0     NaN  ...      12.5
# 1                45.0       52.0     98.0     13.0     NaN  ...       NaN
# ...

# %% [markdown]
# # Imputation

# %% [markdown]
# ## Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean10_imputer = SimpleImputer(strategy='mean')
for i in range(1,1601):
  globals()[f'imputed_mean10_{i}'] = mean10_imputer.fit_transform(globals()[f'data_random{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN10_{i}'] = mean_squared_error(data, globals()[f'imputed_mean10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MEAN= (t_end- t_start)

# %%
MSE_MEAN10_1600
# Out:
# 5042.891190224408

# %%
t_start = time.time()
mse_mean10_total = 0 
for i in range(1,1601):
  mse_mean10_total = mse_mean10_total + globals()[f'MSE_MEAN10_{i}']
AMSE_HeartRate10_mean = mse_mean10_total/1600
print(f'AMSE_HeartRate10_mean = {AMSE_HeartRate10_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_mean = 5028.328836096393
# เวลาที่ใช้ในการประมวลผล 0.009467124938964844 วินาที
# เวลาที่ใช้ในการประมวลผล 0.00015778541564941405 นาที

# %% [markdown]
# ## Miss Forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 KB 3.2 MB/s eta 0:00:00
# ...

# %%
t_start = time.time()
MF10_imputer = MissForest()
for i in range(1,1601):
  globals()[f'imputed_mf10_{i}'] = MF10_imputer.fit_transform(globals()[f'data_random{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF10_{i}'] = mean_squared_error(data, globals()[f'imputed_mf10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MF= (t_end- t_start)

# %%
t_start = time.time()
mse_mf10_total = 0 
for i in range(1,1601):
  mse_mf10_total = mse_mf10_total + globals()[f'MSE_MF10_{i}']
AMSE_HeartRate10_mf = mse_mf10_total/1600
print(f'AMSE_HeartRate10_mf = {AMSE_HeartRate10_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
