# %% [markdown]
# <a href="https://colab.research.google.com/github/Worachet-Ch/project2022/blob/main/random_nan_and_imputation_with_HeartRate_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #นำเข้า pandas แทนที่ด้วย pd
import os# os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as mno
import missingno as msno
from sklearn import linear_model
# %matplotlib inline
import matplotlib
import sklearn 
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
import time

# %%
from google.colab import drive #เชื่อม Google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project' #เข้า drive
data_file_path = os.path.join(path,'data_notmissing.csv') #ไปที่ไฟล์ confirmed-cases-since-280265.csv
data = pd.read_csv(data_file_path) #อ่านไฟล์ csv
# Out:
# Mounted at /content/drive

# %%
data.drop({'Unnamed: 0','telomere length (kb) '},1,inplace = True)
# Out:
# <ipython-input-3-4cc622f169ae>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data.drop({'Unnamed: 0','telomere length (kb) '},1,inplace = True)

# %%
data
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0      107.0
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0       69.0
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# # 10 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate10_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate10_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate10_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.23022198677062988 วินาที
# เวลาที่ใช้ในการประมวลผล 0.003837033112843831 นาที

# %%
HeartRate10_1
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0      107.0
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0       69.0
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean10_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean10_{i}'] = mean10_imputer.fit_transform(globals()[f'HeartRate10_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN10_{i}'] = mean_squared_error(data, globals()[f'imputed_mean10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MEAN= (t_end- t_start)

# %%
MSE_MEAN10_1
# Out:
# 0.5093393706342667

# %%
t_start = time.time()
mse_mean10_total = 0 
MSE_MEAN10_1001 = 0
for i in range(0,1001):
  mse_mean10_total = mse_mean10_total + globals()[f'MSE_MEAN10_{i+1}']
AMSE_HeartRate10_mean = mse_mean10_total/1000
print(f'AMSE_HeartRate10_mean = {AMSE_HeartRate10_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_mean = 0.4001542322566173
# เวลาที่ใช้ในการประมวลผล 0.0010504722595214844 วินาที
# เวลาที่ใช้ในการประมวลผล 1.750787099202474e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting missingpy
#   Downloading missingpy-0.2.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 KB 2.4 MB/s eta 0:00:00
# Installing collected packages: missingpy
# Successfully installed missingpy-0.2.0

# %%
t_start = time.time()
MF10_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf10_{i}'] = MF10_imputer.fit_transform(globals()[f'HeartRate10_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF10_{i}'] = mean_squared_error(data, globals()[f'imputed_mf10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MF= (t_end- t_start)

# %%
t_start = time.time()
mse_mf10_total = 0 
MSE_MF10_1001 = 0
for i in range(0,1001):
  mse_mf10_total = mse_mf10_total + globals()[f'MSE_MF10_{i+1}']
AMSE_HeartRate10_mf = mse_mf10_total/1000
print(f'AMSE_HeartRate10_mf = {AMSE_HeartRate10_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_mf = 0.3876489350930112
# เวลาที่ใช้ในการประมวลผล 0.0014984607696533203 วินาที
# เวลาที่ใช้ในการประมวลผล 2.4974346160888672e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN10_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN10_{i}'] = KNN10_imputer.fit_transform(globals()[f'HeartRate10_{i}'].copy())
  globals()[f'MSE_KNN10_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN10_{i}'])
t_end = time.time()
t10_KNN= (t_end- t_start)

# %%
t_start = time.time()
mse_knn10_total = 0 
MSE_KNN10_1001 = 0
for i in range(0,1001):
  mse_knn10_total = mse_knn10_total + globals()[f'MSE_KNN10_{i+1}']
AMSE_HeartRate10_knn = mse_knn10_total/1000
print(f'AMSE_HeartRate10_knn = {AMSE_HeartRate10_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_knn = 0.41757856432601576
# เวลาที่ใช้ในการประมวลผล 0.0009162425994873047 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5270709991455077e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr10_{i}'] = imp.fit_transform(globals()[f'HeartRate10_{i}'].copy())
  globals()[f'MSE_lr10_{i}'] = mean_squared_error(data, globals()[f'imputed_lr10_{i}'])
t_end = time.time()
t10_LR= (t_end- t_start)

# %%
t_start = time.time()
mse_lr10_total = 0 
MSE_lr10_1001 = 0
for i in range(0,1001):
  mse_lr10_total = mse_lr10_total + globals()[f'MSE_lr10_{i+1}']
AMSE_HeartRate10_lr = mse_lr10_total/1000
print(f'AMSE_HeartRate10_lr = {AMSE_HeartRate10_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_lr = 0.4305995759444558
# เวลาที่ใช้ในการประมวลผล 0.0006988048553466797 วินาที
# เวลาที่ใช้ในการประมวลผล 1.1646747589111328e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm10_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate10_{i}'].copy())
  globals()[f'MSE_svm10_{i}'] = mean_squared_error(data, globals()[f'imputed_svm10_{i}'])
t_end = time.time()
t10_SVM= (t_end- t_start)

# %%
t_start = time.time()
mse_svm10_total = 0 
MSE_svm10_1001 = 0
for i in range(0,1001):
  mse_svm10_total = mse_svm10_total + globals()[f'MSE_svm10_{i+1}']
AMSE_HeartRate10_svm = mse_svm10_total/1000
print(f'AMSE_HeartRate10_svm = {AMSE_HeartRate10_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_svm = 0.3967617777847077
# เวลาที่ใช้ในการประมวลผล 0.0013759136199951172 วินาที
# เวลาที่ใช้ในการประมวลผล 2.2931893666585287e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting impyute
#   Downloading impyute-0.0.8-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Installing collected packages: impyute
# Successfully installed impyute-0.0.8

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy10_{i}'] = impy.em(globals()[f'HeartRate10_{i}'].values.copy())
  globals()[f'MSE_impy10_{i}'] = mean_squared_error(data, globals()[f'imputed_impy10_{i}'])
t_end = time.time()
t10_EM= (t_end- t_start)

# %%
t_start = time.time()
mse_impy10_total = 0 
MSE_impy10_1001 = 0
for i in range(0,1001):
  mse_impy10_total = mse_impy10_total + globals()[f'MSE_impy10_{i+1}']
AMSE_HeartRate10_impy = mse_impy10_total/1000
print(f'AMSE_HeartRate10_impy = {AMSE_HeartRate10_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate10_impy = 0.7507072077771878
# เวลาที่ใช้ในการประมวลผล 0.0007410049438476562 วินาที
# เวลาที่ใช้ในการประมวลผล 1.2350082397460937e-05 นาที

# %% [markdown]
# # 20 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate20_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*20/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate20_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate20_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.1620335578918457 วินาที
# เวลาที่ใช้ในการประมวลผล 0.0027005592981974285 นาที

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean20_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean20_{i}'] = mean20_imputer.fit_transform(globals()[f'HeartRate20_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN20_{i}'] = mean_squared_error(data, globals()[f'imputed_mean20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean20_total = 0 
MSE_MEAN20_1001 = 0
for i in range(0,1001):
  mse_mean20_total = mse_mean20_total + globals()[f'MSE_MEAN20_{i+1}']
AMSE_HeartRate20_mean = mse_mean20_total/1000
print(f'AMSE_HeartRate20_mean = {AMSE_HeartRate20_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_mean = 0.7979783501903731
# เวลาที่ใช้ในการประมวลผล 0.0009005069732666016 วินาที
# เวลาที่ใช้ในการประมวลผล 1.500844955444336e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF20_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf20_{i}'] = MF20_imputer.fit_transform(globals()[f'HeartRate20_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF20_{i}'] = mean_squared_error(data, globals()[f'imputed_mf20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf20_total = 0 
MSE_MF20_1001 = 0
for i in range(0,1001):
  mse_mf20_total = mse_mf20_total + globals()[f'MSE_MF20_{i+1}']
AMSE_HeartRate20_mf = mse_mf20_total/1000
print(f'AMSE_HeartRate20_mf = {AMSE_HeartRate20_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_mf = 0.7780869488939163
# เวลาที่ใช้ในการประมวลผล 0.0015759468078613281 วินาที
# เวลาที่ใช้ในการประมวลผล 2.6265780131022137e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN20_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN20_{i}'] = KNN20_imputer.fit_transform(globals()[f'HeartRate20_{i}'].copy())
  globals()[f'MSE_KNN20_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN20_{i}'])
t_end = time.time()
t20_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn20_total = 0 
MSE_KNN20_1001 = 0
for i in range(0,1001):
  mse_knn20_total = mse_knn20_total + globals()[f'MSE_KNN20_{i+1}']
AMSE_HeartRate20_knn = mse_knn20_total/1000
print(f'AMSE_HeartRate20_knn = {AMSE_HeartRate20_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_knn = 0.834956069493325
# เวลาที่ใช้ในการประมวลผล 0.0010466575622558594 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7444292704264324e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr20_{i}'] = imp.fit_transform(globals()[f'HeartRate20_{i}'].copy())
  globals()[f'MSE_lr20_{i}'] = mean_squared_error(data, globals()[f'imputed_lr20_{i}'])
t_end = time.time()
t20_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr20_total = 0 
MSE_lr20_1001 = 0
for i in range(0,1001):
  mse_lr20_total = mse_lr20_total + globals()[f'MSE_lr20_{i+1}']
AMSE_HeartRate20_lr = mse_lr20_total/1000
print(f'AMSE_HeartRate20_lr = {AMSE_HeartRate20_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_lr = 0.9345934258985457
# เวลาที่ใช้ในการประมวลผล 0.0015499591827392578 วินาที
# เวลาที่ใช้ในการประมวลผล 2.5832653045654296e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm20_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate20_{i}'].copy())
  globals()[f'MSE_svm20_{i}'] = mean_squared_error(data, globals()[f'imputed_svm20_{i}'])
t_end = time.time()
t20_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm20_total = 0 
MSE_svm20_1001 = 0
for i in range(0,1001):
  mse_svm20_total = mse_svm20_total + globals()[f'MSE_svm20_{i+1}']
AMSE_HeartRate20_svm = mse_svm20_total/1000
print(f'AMSE_HeartRate20_svm = {AMSE_HeartRate20_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_svm = 0.7925690179217645
# เวลาที่ใช้ในการประมวลผล 0.0009818077087402344 วินาที
# เวลาที่ใช้ในการประมวลผล 1.636346181233724e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy20_{i}'] = impy.em(globals()[f'HeartRate20_{i}'].values.copy())
  globals()[f'MSE_impy20_{i}'] = mean_squared_error(data, globals()[f'imputed_impy20_{i}'])
t_end = time.time()
t20_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy20_total = 0 
MSE_impy20_1001 = 0
for i in range(0,1001):
  mse_impy20_total = mse_impy20_total + globals()[f'MSE_impy20_{i+1}']
AMSE_HeartRate20_impy = mse_impy20_total/1000
print(f'AMSE_HeartRate20_impy = {AMSE_HeartRate20_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate20_impy = 1.4940363757612645
# เวลาที่ใช้ในการประมวลผล 0.0016162395477294922 วินาที
# เวลาที่ใช้ในการประมวลผล 2.6937325795491537e-05 นาที

# %% [markdown]
# # 30 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate30_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*30/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate30_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate30_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.22190332412719727 วินาที
# เวลาที่ใช้ในการประมวลผล 0.0036983887354532876 นาที

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean30_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean30_{i}'] = mean30_imputer.fit_transform(globals()[f'HeartRate30_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN30_{i}'] = mean_squared_error(data, globals()[f'imputed_mean30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean30_total = 0 
MSE_MEAN30_1001 = 0
for i in range(0,1001):
  mse_mean30_total = mse_mean30_total + globals()[f'MSE_MEAN30_{i+1}']
AMSE_HeartRate30_mean = mse_mean30_total/1000
print(f'AMSE_HeartRate30_mean = {AMSE_HeartRate30_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_mean = 1.2102241865367547
# เวลาที่ใช้ในการประมวลผล 0.0025568008422851562 วินาที
# เวลาที่ใช้ในการประมวลผล 4.261334737141927e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF30_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf30_{i}'] = MF30_imputer.fit_transform(globals()[f'HeartRate30_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF30_{i}'] = mean_squared_error(data, globals()[f'imputed_mf30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf30_total = 0 
MSE_MF30_1001 = 0
for i in range(0,1001):
  mse_mf30_total = mse_mf30_total + globals()[f'MSE_MF30_{i+1}']
AMSE_HeartRate30_mf = mse_mf30_total/1000
print(f'AMSE_HeartRate30_mf = {AMSE_HeartRate30_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_mf = 1.1938357610608348
# เวลาที่ใช้ในการประมวลผล 0.001482248306274414 วินาที
# เวลาที่ใช้ในการประมวลผล 2.47041384379069e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN30_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN30_{i}'] = KNN30_imputer.fit_transform(globals()[f'HeartRate30_{i}'].copy())
  globals()[f'MSE_KNN30_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN30_{i}'])
t_end = time.time()
t30_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn30_total = 0 
MSE_KNN30_1001 = 0
for i in range(0,1001):
  mse_knn30_total = mse_knn30_total + globals()[f'MSE_KNN30_{i+1}']
AMSE_HeartRate30_knn = mse_knn30_total/1000
print(f'AMSE_HeartRate30_knn = {AMSE_HeartRate30_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_knn = 1.2633237472766896
# เวลาที่ใช้ในการประมวลผล 0.0009305477142333984 วินาที
# เวลาที่ใช้ในการประมวลผล 1.550912857055664e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr30_{i}'] = imp.fit_transform(globals()[f'HeartRate30_{i}'].copy())
  globals()[f'MSE_lr30_{i}'] = mean_squared_error(data, globals()[f'imputed_lr30_{i}'])
t_end = time.time()
t30_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr30_total = 0 
MSE_lr30_1001 = 0
for i in range(0,1001):
  mse_lr30_total = mse_lr30_total + globals()[f'MSE_lr30_{i+1}']
AMSE_HeartRate30_lr = mse_lr30_total/1000
print(f'AMSE_HeartRate30_lr = {AMSE_HeartRate30_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_lr = 1.6086221132572425
# เวลาที่ใช้ในการประมวลผล 0.0014197826385498047 วินาที
# เวลาที่ใช้ในการประมวลผล 2.3663043975830078e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm30_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate30_{i}'].copy())
  globals()[f'MSE_svm30_{i}'] = mean_squared_error(data, globals()[f'imputed_svm30_{i}'])
t_end = time.time()
t30_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm30_total = 0 
MSE_svm30_1001 = 0
for i in range(0,1001):
  mse_svm30_total = mse_svm30_total + globals()[f'MSE_svm30_{i+1}']
AMSE_HeartRate30_svm = mse_svm30_total/1000
print(f'AMSE_HeartRate30_svm = {AMSE_HeartRate30_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_svm = 1.208569968579968
# เวลาที่ใช้ในการประมวลผล 0.0011093616485595703 วินาที
# เวลาที่ใช้ในการประมวลผล 1.848936080932617e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy30_{i}'] = impy.em(globals()[f'HeartRate30_{i}'].values.copy())
  globals()[f'MSE_impy30_{i}'] = mean_squared_error(data, globals()[f'imputed_impy30_{i}'])
t_end = time.time()
t30_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy30_total = 0 
MSE_impy30_1001 = 0
for i in range(0,1001):
  mse_impy30_total = mse_impy30_total + globals()[f'MSE_impy30_{i+1}']
AMSE_HeartRate30_impy = mse_impy30_total/1000
print(f'AMSE_HeartRate30_impy = {AMSE_HeartRate30_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate30_impy = 2.2415128278537573
# เวลาที่ใช้ในการประมวลผล 0.0013575553894042969 วินาที
# เวลาที่ใช้ในการประมวลผล 2.2625923156738283e-05 นาที

# %% [markdown]
# # 40 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate40_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*40/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate40_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate40_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.18543410301208496 วินาที
# เวลาที่ใช้ในการประมวลผล 0.0030905683835347492 นาที

# %%
HeartRate40_1
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0        NaN
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0        NaN
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean40_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean40_{i}'] = mean40_imputer.fit_transform(globals()[f'HeartRate40_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN40_{i}'] = mean_squared_error(data, globals()[f'imputed_mean40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean40_total = 0 
MSE_MEAN40_1001 = 0
for i in range(0,1001):
  mse_mean40_total = mse_mean40_total + globals()[f'MSE_MEAN40_{i+1}']
AMSE_HeartRate40_mean = mse_mean40_total/1000
print(f'AMSE_HeartRate40_mean = {AMSE_HeartRate40_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_mean = 1.6470303441731984
# เวลาที่ใช้ในการประมวลผล 0.0010678768157958984 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7797946929931642e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF40_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf40_{i}'] = MF40_imputer.fit_transform(globals()[f'HeartRate40_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF40_{i}'] = mean_squared_error(data, globals()[f'imputed_mf40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf40_total = 0 
MSE_MF40_1001 = 0
for i in range(0,1001):
  mse_mf40_total = mse_mf40_total + globals()[f'MSE_MF40_{i+1}']
AMSE_HeartRate40_mf = mse_mf40_total/1000
print(f'AMSE_HeartRate40_mf = {AMSE_HeartRate40_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_mf = 1.644458566540973
# เวลาที่ใช้ในการประมวลผล 0.001216888427734375 วินาที
# เวลาที่ใช้ในการประมวลผล 2.0281473795572916e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN40_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN40_{i}'] = KNN40_imputer.fit_transform(globals()[f'HeartRate40_{i}'].copy())
  globals()[f'MSE_KNN40_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN40_{i}'])
t_end = time.time()
t40_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn40_total = 0 
MSE_KNN40_1001 = 0
for i in range(0,1001):
  mse_knn40_total = mse_knn40_total + globals()[f'MSE_KNN40_{i+1}']
AMSE_HeartRate40_knn = mse_knn40_total/1000
print(f'AMSE_HeartRate40_knn = {AMSE_HeartRate40_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_knn = 1.7155649360370924
# เวลาที่ใช้ในการประมวลผล 0.001062631607055664 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7710526784261067e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr40_{i}'] = imp.fit_transform(globals()[f'HeartRate40_{i}'].copy())
  globals()[f'MSE_lr40_{i}'] = mean_squared_error(data, globals()[f'imputed_lr40_{i}'])
t_end = time.time()
t40_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr40_total = 0 
MSE_lr40_1001 = 0
for i in range(0,1001):
  mse_lr40_total = mse_lr40_total + globals()[f'MSE_lr40_{i+1}']
AMSE_HeartRate40_lr = mse_lr40_total/1000
print(f'AMSE_HeartRate40_lr = {AMSE_HeartRate40_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_lr = 2.6125714011229313
# เวลาที่ใช้ในการประมวลผล 0.0010838508605957031 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8064181009928385e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm40_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate40_{i}'].copy())
  globals()[f'MSE_svm40_{i}'] = mean_squared_error(data, globals()[f'imputed_svm40_{i}'])
t_end = time.time()
t40_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm40_total = 0 
MSE_svm40_1001 = 0
for i in range(0,1001):
  mse_svm40_total = mse_svm40_total + globals()[f'MSE_svm40_{i+1}']
AMSE_HeartRate40_svm = mse_svm40_total/1000
print(f'AMSE_HeartRate40_svm = {AMSE_HeartRate40_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_svm = 1.6514443739805118
# เวลาที่ใช้ในการประมวลผล 0.0018200874328613281 วินาที
# เวลาที่ใช้ในการประมวลผล 3.0334790547688802e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy40_{i}'] = impy.em(globals()[f'HeartRate40_{i}'].values.copy())
  globals()[f'MSE_impy40_{i}'] = mean_squared_error(data, globals()[f'imputed_impy40_{i}'])
t_end = time.time()
t40_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy40_total = 0 
MSE_impy40_1001 = 0
for i in range(0,1001):
  mse_impy40_total = mse_impy40_total + globals()[f'MSE_impy40_{i+1}']
AMSE_HeartRate40_impy = mse_impy40_total/1000
print(f'AMSE_HeartRate40_impy = {AMSE_HeartRate40_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate40_impy = 3.061811880716946
# เวลาที่ใช้ในการประมวลผล 0.0011646747589111328 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9411245981852215e-05 นาที

# %% [markdown]
# # 50 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate50_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*50/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate50_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate50_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.15957093238830566 วินาที
# เวลาที่ใช้ในการประมวลผล 0.0026595155398050946 นาที

# %%
HeartRate50_1
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0        NaN
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0        NaN
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0        NaN
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0        NaN
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean50_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean50_{i}'] = mean50_imputer.fit_transform(globals()[f'HeartRate50_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN50_{i}'] = mean_squared_error(data, globals()[f'imputed_mean50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean50_total = 0 
MSE_MEAN50_1001 = 0
for i in range(0,1001):
  mse_mean50_total = mse_mean50_total + globals()[f'MSE_MEAN50_{i+1}']
AMSE_HeartRate50_mean = mse_mean50_total/1000
print(f'AMSE_HeartRate50_mean = {AMSE_HeartRate50_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_mean = 2.061385750867415
# เวลาที่ใช้ในการประมวลผล 0.0009872913360595703 วินาที
# เวลาที่ใช้ในการประมวลผล 1.645485560099284e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF50_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf50_{i}'] = MF50_imputer.fit_transform(globals()[f'HeartRate50_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF50_{i}'] = mean_squared_error(data, globals()[f'imputed_mf50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf50_total = 0 
MSE_MF50_1001 = 0
for i in range(0,1001):
  mse_mf50_total = mse_mf50_total + globals()[f'MSE_MF50_{i+1}']
AMSE_HeartRate50_mf = mse_mf50_total/1000
print(f'AMSE_HeartRate50_mf = {AMSE_HeartRate50_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_mf = 2.083153801458018
# เวลาที่ใช้ในการประมวลผล 0.0012302398681640625 วินาที
# เวลาที่ใช้ในการประมวลผล 2.0503997802734375e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN50_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN50_{i}'] = KNN50_imputer.fit_transform(globals()[f'HeartRate50_{i}'].copy())
  globals()[f'MSE_KNN50_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN50_{i}'])
t_end = time.time()
t50_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn50_total = 0 
MSE_KNN50_1001 = 0
for i in range(0,1001):
  mse_knn50_total = mse_knn50_total + globals()[f'MSE_KNN50_{i+1}']
AMSE_HeartRate50_knn = mse_knn50_total/1000
print(f'AMSE_HeartRate50_knn = {AMSE_HeartRate50_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_knn = 2.1327765130439635
# เวลาที่ใช้ในการประมวลผล 0.005286693572998047 วินาที
# เวลาที่ใช้ในการประมวลผล 8.811155954996745e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr50_{i}'] = imp.fit_transform(globals()[f'HeartRate50_{i}'].copy())
  globals()[f'MSE_lr50_{i}'] = mean_squared_error(data, globals()[f'imputed_lr50_{i}'])
t_end = time.time()
t50_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr50_total = 0 
MSE_lr50_1001 = 0
for i in range(0,1001):
  mse_lr50_total = mse_lr50_total + globals()[f'MSE_lr50_{i+1}']
AMSE_HeartRate50_lr = mse_lr50_total/1000
print(f'AMSE_HeartRate50_lr = {AMSE_HeartRate50_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_lr = 4.1558860170659155
# เวลาที่ใช้ในการประมวลผล 0.001055002212524414 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7583370208740234e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm50_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate50_{i}'].copy())
  globals()[f'MSE_svm50_{i}'] = mean_squared_error(data, globals()[f'imputed_svm50_{i}'])
t_end = time.time()
t50_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm50_total = 0 
MSE_svm50_1001 = 0
for i in range(0,1001):
  mse_svm50_total = mse_svm50_total + globals()[f'MSE_svm50_{i+1}']
AMSE_HeartRate50_svm = mse_svm50_total/1000
print(f'AMSE_HeartRate50_svm = {AMSE_HeartRate50_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_svm = 2.0751983620943744
# เวลาที่ใช้ในการประมวลผล 0.0010268688201904297 วินาที
# เวลาที่ใช้ในการประมวลผล 1.711448033650716e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy50_{i}'] = impy.em(globals()[f'HeartRate50_{i}'].values.copy())
  globals()[f'MSE_impy50_{i}'] = mean_squared_error(data, globals()[f'imputed_impy50_{i}'])
t_end = time.time()
t50_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy50_total = 0 
MSE_impy50_1001 = 0
for i in range(0,1001):
  mse_impy50_total = mse_impy50_total + globals()[f'MSE_impy50_{i+1}']
AMSE_HeartRate50_impy = mse_impy50_total/1000
print(f'AMSE_HeartRate50_impy = {AMSE_HeartRate50_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate50_impy = 3.8490750031277994
# เวลาที่ใช้ในการประมวลผล 0.0014483928680419922 วินาที
# เวลาที่ใช้ในการประมวลผล 2.4139881134033203e-05 นาที

# %% [markdown]
# # 60 % random nan

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'HeartRate60_{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*60/100)) 
  index_nan = np.random.choice(globals()[f'HeartRate60_{i}']['HeartRate'].size, n, replace=False) #globals()[name dataframe][column name].size
  globals()[f'HeartRate60_{i}']['HeartRate'].ravel()[index_nan] = np.nan
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# เวลาที่ใช้ในการประมวลผล 0.16895079612731934 วินาที
# เวลาที่ใช้ในการประมวลผล 0.002815846602121989 นาที

# %%
HeartRate60_1
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0        NaN
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0        NaN
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0        NaN
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0        NaN
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0        NaN
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0        NaN
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean60_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean60_{i}'] = mean50_imputer.fit_transform(globals()[f'HeartRate60_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN60_{i}'] = mean_squared_error(data, globals()[f'imputed_mean60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean60_total = 0 
MSE_MEAN60_1001 = 0
for i in range(0,1001):
  mse_mean60_total = mse_mean60_total + globals()[f'MSE_MEAN60_{i+1}']
AMSE_HeartRate60_mean = mse_mean60_total/1000
print(f'AMSE_HeartRate60_mean = {AMSE_HeartRate60_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_mean = 2.473666653456649
# เวลาที่ใช้ในการประมวลผล 0.001188039779663086 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9800662994384765e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF60_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf60_{i}'] = MF60_imputer.fit_transform(globals()[f'HeartRate60_{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF60_{i}'] = mean_squared_error(data, globals()[f'imputed_mf60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MF = (t_end- t_start)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# Iteration: 5
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 6
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# Iteration: 5
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 6
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 5
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 5
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 5
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# ...
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 4
# Iteration: 5
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 6
# Iteration: 7
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 4
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 3
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 0
# Iteration: 1
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 2
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 3
# Iteration: 0
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# Iteration: 1
# Iteration: 2
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(

# %%
t_start = time.time()
mse_mf60_total = 0 
MSE_MF60_1001 = 0
for i in range(0,1001):
  mse_mf60_total = mse_mf60_total + globals()[f'MSE_MF60_{i+1}']
AMSE_HeartRate60_mf = mse_mf60_total/1000
print(f'AMSE_HeartRate60_mf = {AMSE_HeartRate60_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_mf = 2.5270525878079417
# เวลาที่ใช้ในการประมวลผล 0.0021719932556152344 วินาที
# เวลาที่ใช้ในการประมวลผล 3.619988759358724e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN60_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN60_{i}'] = KNN60_imputer.fit_transform(globals()[f'HeartRate60_{i}'].copy())
  globals()[f'MSE_KNN60_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN60_{i}'])
t_end = time.time()
t60_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn60_total = 0 
MSE_KNN60_1001 = 0
for i in range(0,1001):
  mse_knn60_total = mse_knn60_total + globals()[f'MSE_KNN60_{i+1}']
AMSE_HeartRate60_knn = mse_knn60_total/1000
print(f'AMSE_HeartRate60_knn = {AMSE_HeartRate60_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_knn = 2.52500800178761
# เวลาที่ใช้ในการประมวลผล 0.005290985107421875 วินาที
# เวลาที่ใช้ในการประมวลผล 8.818308512369792e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr60_{i}'] = imp.fit_transform(globals()[f'HeartRate60_{i}'].copy())
  globals()[f'MSE_lr60_{i}'] = mean_squared_error(data, globals()[f'imputed_lr60_{i}'])
t_end = time.time()
t60_LR = (t_end- t_start)
# Out:
# Streaming output truncated to the last 5000 lines.
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 53.85226916548031, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 133.05507639478208, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 55.535360936705644, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 32.50541661076787, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 54.82477920276597, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 90.31248915471927, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 123.90321988090355, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.743422328697378, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 209.14113940296437, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 26.15119947019562, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 191.3982446118343, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 30.956375847798867, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 58.21848282201695, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.888124260794584, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 44.24271563264634, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 68.96926012980487, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 50.07368764448421, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 71.84499666869009, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 20.862597832857304, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 41.39263137305133, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 38.38709738335568, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 31.300788819130773, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 18.005902509686827, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 98.21252036280845, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 40.89401163545287, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 150.23753902603283, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 36.50433375217398, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 42.23022617423079, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 21.04086931970214, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 26.490640421764866, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 18.36799799361986, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 33.45778315447913, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 125.10603947719875, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 153.28400340612725, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 45.87997455949025, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 38.38607221767036, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 144.07628744255652, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 318.7457313817032, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.75451963329786, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 30.83539141781712, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 15.729850208627823, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 27.301066022984287, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 186.66418315854756, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 29.006623808468667, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 22.19687599245026, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 20.40410525425014, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 27.77377805500933, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 27.55365737513138, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 126.83124504601427, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 366.33015413786666, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 35.66942538519499, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 45.39897811243887, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 35.765673652792216, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 46.056745815069036, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 78.98459372105985, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 23.856436767100192, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 54.20883314355943, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 532.8275826850851, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 157.45766057223088, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 31.795743859495076, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 112.40079623601888, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.43905154947258, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.750415241039548, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 310.20996857913514, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 141.3271223815894, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 163.1573272207237, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 297.5321296963088, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 35.10475896915075, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 92.76649549783968, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 34.592432394591285, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 224.45365505093207, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 38.48067168095079, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 33.40822159655666, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 28.28744616878474, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 74.88313578882828, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 30.452660518798396, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 24.377553631278687, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 33.89396833674763, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 79.28928066343167, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 21.333173658113168, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 22.559704631439416, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 38.14616673318878, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 198.37216751118993, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 31.050119621596394, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 40.488575731381545, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 20.066275066262904, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 43.92512612574133, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 26.69438264585915, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 32.67747488644511, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 32.72499065130944, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 109.03348937615421, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 40.39352132606564, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 47.65931261030718, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 80.4697770363325, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 296.14367400364995, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.697188528647175, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 27.663570755581375, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 32.82042340621177, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 203.60518735818727, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 178.18500788003303, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 210.08738433549127, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 70.28690805124525, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 184.054698973649, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 34.9860893342948, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 270.67978388286735, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 45.337311793789496, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 119.06910712656432, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 23.442903876448128, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 52.76366149876431, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 37.9646449434505, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 53.96209522640318, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 214.0937380949498, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 21.628683285340983, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 30.398326448844912, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 255.036904070004, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 40.09929626781863, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 44.366721340924116, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 129.56074335186364, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 40.20397613154401, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 45.32452733428717, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 21.18705006271982, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.30425945217732, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 101.101477689538, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 69.04720224518589, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 26.28780399436748, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 171.64361392011224, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 37.009883011062186, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.70619990251572, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# ...
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 52.80451247964808, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 170.02234098787335, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.367696377009224, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.800565854399977, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 155.83663308578124, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 18.472079084097643, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 20.756961020355803, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 78.49209904544557, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 51.28800490561197, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 54.220494630862575, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 22.4787456414917, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 31.508762225911013, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 51.45488440567702, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 37.607600252143456, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 281.71665820726895, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 17.649462458355387, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 298.5612723326748, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 191.9401750833377, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 58.08134775774457, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 40.54613404658849, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 55.59234867045892, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 107.76806646848867, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 191.39616748062707, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.33622967681015, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 26.60499737075442, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 44.159519656959404, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 26.406869400713504, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 48.45289239470311, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 29.95911547724674, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 20.11699386248631, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 308.8484619342558, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 457.70676209365075, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 33.073297146441234, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 36.80814286119157, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 256.8137696154122, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 24.25923847191666, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 350.745008370595, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 59.47359095362084, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 25.32410073720807, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 27.539844320620404, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 91.56838266844909, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 62.302181706602624, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 33.92827992068682, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.04
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.

# %%
t_start = time.time()
mse_lr60_total = 0 
MSE_lr60_1001 = 0
for i in range(0,1001):
  mse_lr60_total = mse_lr60_total + globals()[f'MSE_lr60_{i+1}']
AMSE_HeartRate60_lr = mse_lr60_total/1000
print(f'AMSE_HeartRate60_lr = {AMSE_HeartRate60_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_lr = 7.780793628604541
# เวลาที่ใช้ในการประมวลผล 0.0011222362518310547 วินาที
# เวลาที่ใช้ในการประมวลผล 1.870393753051758e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm60_{i}'] = svm_svr.fit_transform(globals()[f'HeartRate60_{i}'].copy())
  globals()[f'MSE_svm60_{i}'] = mean_squared_error(data, globals()[f'imputed_svm60_{i}'])
t_end = time.time()
t60_SVM = (t_end- t_start)
# Out:
# Streaming output truncated to the last 5000 lines.
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.3611373655910626, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.2181898669186353, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.7651710809950174, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9976052345962074, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.1199629339062085, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.1412449797309137, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 2.713585991564983, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.085829587110865, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.5213801956111865, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.2408936676698374, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.0458131227164245, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.411030627117782, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.183862493501209, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.97581577383896, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.5169704037072904, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1440529017802703, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.028807634143334, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.8341087807231133, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.31257532233424, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 0.9666187662474073, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7257301687512694, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.868876388750195, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.6408940353576895, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.438738200829121, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.4636078282171923, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.3073209779895762, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.0587947747837632, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.4194462712838742, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.2872270770916998, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.4408643353780803, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.564110191602083, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.0556251040853226, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.142448437928593, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.4796059541242954, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.4090121073756166, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7108920552727653, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.7607945990726535, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.223159970096873, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.5089547122521623, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.8150766382521226, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.3071996591961863, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.462549922075226, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.7814463181631197, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9019937996522174, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.693829918113579, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.455813531862546, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.1578321309785338, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 4.314452194677102, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.92704164442533, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.7586627369642542, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0308468103663984, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.532602312239561, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.9113575236926295, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.433811737237818, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.8262749916001582, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.102092387832215, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.4628901571086743, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.3345213885575617, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 2.1639886558157713, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.5368605293619737, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.5371119621391642, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.6385221239633694, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.586384496405799, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.3487023817591677, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.4059302848286563, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.5870846684536417, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.4148700746924874, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.7069402605777384, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.7615863844830812, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.7092413576749266, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.221063389955134, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.1901253457482994, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.3245556970286145, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.70850090366433, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.8456421487483965, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.8908133732096246, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.253419619264335, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.6039403484526673, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.647299672792883, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.6800429997241935, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.3132481942495815, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.0073898584312246, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.8003940135115784, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.216963965663865, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.416367700740949, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.779853138323162, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.891442479311806, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.60278436045364, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.733579889503389, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.2543981537172613, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0044112867749817, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.046350704785226, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.7082521336593146, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.213920342540547, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5569168468194192, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.455771405607294, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.704342685543267, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.9962788693693625, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.3675074471452007, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.588191779137304, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.8099181980195738, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.629384405447709, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 0.939802111300196, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.731866266406641, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.1433393693048117, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.6630877693761335, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.304615177251904, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9371349054361247, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9851462853679607, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.37599380447503, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.125588612299893, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.477732189341822, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.24661227300966, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.0703197515293255, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.5123282777321663, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.8835012735418246, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.6425694285279633, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 0.9838406473509593, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.5922874003965006, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.915551829434861, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.49630432527052903, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.941886674946602, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.00791341408906, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7096120924519909, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.281404506798367, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.8529902176002366, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.9596859750285205, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.0160904469607317, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# ...
# [IterativeImputer] Change: 2.3772194026600886, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.0690048475759255, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7453229995504955, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.194052486287191, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.4717143527571324, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9130062615903114, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.0668090140005546, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 0.8223140383167618, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.405007451802632, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.5075248392269458, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7977808255771066, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 3.543705665405426, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.7384459098527003, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.356946569808784, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 4.009549035920571, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.822295156306126, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.6350847436804372, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.3266006109372057, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.170033629564827, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.2707759530676555, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.9140727164252382, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.8112882899081484, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.977475169837291, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.0907306888112487, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.4999029814105285, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.4458803289939794, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.160840079975074, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.7525626549323192, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.565179464723144, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.534933101258389, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.141566191055972, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.1861778736499815, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 1.1768516590037166, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.215628441342318, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.9148182931828757, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.9459158010305657, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.7079282196589816, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.8000834947452375, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.003461664839392, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 3.506937885230755, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.555010945304815, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.11
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.05
# [IterativeImputer] Change: 2.3972790433545867, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.10
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.3549161509070728, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.

# %%
t_start = time.time()
mse_svm60_total = 0 
MSE_svm60_1001 = 0
for i in range(0,1001):
  mse_svm60_total = mse_svm60_total + globals()[f'MSE_svm60_{i+1}']
AMSE_HeartRate60_svm = mse_svm60_total/1000
print(f'AMSE_HeartRate60_svm = {AMSE_HeartRate60_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_svm = 2.4959784903913267
# เวลาที่ใช้ในการประมวลผล 0.0022776126861572266 วินาที
# เวลาที่ใช้ในการประมวลผล 3.7960211435953776e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy60_{i}'] = impy.em(globals()[f'HeartRate60_{i}'].values.copy())
  globals()[f'MSE_impy60_{i}'] = mean_squared_error(data, globals()[f'imputed_impy60_{i}'])
t_end = time.time()
t60_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy60_total = 0 
MSE_impy60_1001 = 0
for i in range(0,1001):
  mse_impy60_total = mse_impy60_total + globals()[f'MSE_impy60_{i+1}']
AMSE_HeartRate60_impy = mse_impy60_total/1000
print(f'AMSE_HeartRate60_impy = {AMSE_HeartRate60_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HeartRate60_impy = 4.66028107646081
# เวลาที่ใช้ในการประมวลผล 0.0010197162628173828 วินาที
# เวลาที่ใช้ในการประมวลผล 1.699527104695638e-05 นาที

# %% [markdown]
# # AMSE

# %%
amse_value = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],
              '10%':[AMSE_HeartRate10_mean,AMSE_HeartRate10_mf,AMSE_HeartRate10_knn,AMSE_HeartRate10_lr,AMSE_HeartRate10_svm,AMSE_HeartRate10_impy],
      '20%':[AMSE_HeartRate20_mean,AMSE_HeartRate20_mf,AMSE_HeartRate20_knn,AMSE_HeartRate20_lr,AMSE_HeartRate20_svm,AMSE_HeartRate20_impy],
      '30%':[AMSE_HeartRate30_mean,AMSE_HeartRate30_mf,AMSE_HeartRate30_knn,AMSE_HeartRate30_lr,AMSE_HeartRate30_svm,AMSE_HeartRate30_impy],
      '40%':[AMSE_HeartRate40_mean,AMSE_HeartRate40_mf,AMSE_HeartRate40_knn,AMSE_HeartRate40_lr,AMSE_HeartRate40_svm,AMSE_HeartRate40_impy],
      '50%':[AMSE_HeartRate50_mean,AMSE_HeartRate50_mf,AMSE_HeartRate50_knn,AMSE_HeartRate50_lr,AMSE_HeartRate60_svm,AMSE_HeartRate50_impy]
      ,'60%':[AMSE_HeartRate60_mean,AMSE_HeartRate60_mf,AMSE_HeartRate60_knn,AMSE_HeartRate60_lr,AMSE_HeartRate60_svm,AMSE_HeartRate60_impy]}

# %%
data_AMSE = pd.DataFrame.from_dict(amse_value)
data_AMSE
# Out:
#         Method       10%       20%       30%       40%       50%       60%
# 0         MEAN  0.400154  0.797978  1.210224  1.647030  2.061386  2.473667
# 1  Miss Forest  0.387649  0.778087  1.193836  1.644459  2.083154  2.527053
# 2          KNN  0.417579  0.834956  1.263324  1.715565  2.132777  2.525008
# 3      MICE-LR  0.430600  0.934593  1.608622  2.612571  4.155886  7.780794
# 4     MICE-SVM  0.396762  0.792569  1.208570  1.651444  2.495978  2.495978
# 5           EM  0.750707  1.494036  2.241513  3.061812  3.849075  4.660281

# %% [markdown]
# # เวลาทั้งหมดในการรัน

# %% [markdown]
# ## second time

# %%
data_t_sec = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN,t10_MF,t10_KNN,t10_LR,t10_SVM,t10_EM],
      '20%':[t20_MEAN,t20_MF,t20_KNN,t20_LR,t20_SVM,t20_EM],'30%':[t30_MEAN,t30_MF,t30_KNN,t30_LR,t30_SVM,t30_EM],'40%':[t40_MEAN,t40_MF,t40_KNN,t40_LR,t40_SVM,t40_EM],
      '50%':[t50_MEAN,t50_MF,t50_KNN,t50_LR,t50_SVM,t50_EM],'60%':[t60_MEAN,t60_MF,t60_KNN,t60_LR,t60_SVM,t60_EM]}

# %%
data_second = pd.DataFrame.from_dict(data_t_sec)
data_second
# Out:
#         Method         10%         20%         30%         40%         50%  \
# 0         MEAN    3.804375    3.799155    4.372938    4.506914    3.969561
# 1  Miss Forest  717.753736  705.310418  712.049996  706.741474  681.270591
# 2          KNN    4.541007    4.757962    4.976356    5.295111    8.575091
# 3      MICE-LR   49.969371   51.438349   51.811382   54.693660   51.133636
# 4     MICE-SVM  112.767525  113.592143  114.175968  115.329765  116.586836
# 5           EM    6.194041   11.158983   17.777943   23.262985   28.334584
#
#           60%
# 0    3.995783
# 1  684.197684
# 2    9.801662
# 3   53.991243
# 4  116.967814
# 5   30.250012

# %% [markdown]
# ## minutes

# %%
data_t_min = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN/60,t10_MF/60,t10_KNN/60,t10_LR/60,t10_SVM/60,t10_EM/60],
      '20%':[t20_MEAN/60,t20_MF/60,t20_KNN/60,t20_LR/60,t20_SVM/60,t20_EM/60],'30%':[t30_MEAN/60,t30_MF/60,t30_KNN/60,t30_LR/60,t30_SVM/60,t30_EM/60]
      ,'40%':[t40_MEAN/60,t40_MF/60,t40_KNN/60,t40_LR/60,t40_SVM/60,t40_EM/60],'50%':[t50_MEAN/60,t50_MF/60,t50_KNN/60,t50_LR/60,t50_SVM/60,t50_EM/60],
      '60%':[t60_MEAN/60,t60_MF/60,t60_KNN/60,t60_LR/60,t60_SVM/60,t60_EM/60]}

# %%
data_minutes = pd.DataFrame.from_dict(data_t_min)
data_minutes
# Out:
#         Method        10%        20%        30%        40%        50%  \
# 0         MEAN   0.063406   0.063319   0.072882   0.075115   0.066159
# 1  Miss Forest  11.962562  11.755174  11.867500  11.779025  11.354510
# 2          KNN   0.075683   0.079299   0.082939   0.088252   0.142918
# 3      MICE-LR   0.832823   0.857306   0.863523   0.911561   0.852227
# 4     MICE-SVM   1.879459   1.893202   1.902933   1.922163   1.943114
# 5           EM   0.103234   0.185983   0.296299   0.387716   0.472243
#
#          60%
# 0   0.066596
# 1  11.403295
# 2   0.163361
# 3   0.899854
# 4   1.949464
# 5   0.504167
